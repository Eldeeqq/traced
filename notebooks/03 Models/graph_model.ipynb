# %%
from trct.models.graph_model import GraphModel

# %%
gm = GraphModel("src", "dest")

# %%
gm.log(0, ["a", "b", "dest"])

# %%
gm.log(1, ["a", "b", "c"])

# %%
gm.log(2, ["b", "d", "dest"])

# %%
g=  gm.to_graph()

# %%
import netgraph as ng

# %%
g.nodes(data=True)
# Out:
# NodeDataView({0: {}, 1: {}, 2: {}, 3: {}, 4: {}, 5: {}})

# %%
gm.nodes
# Out:
# OrderedDict([('src', 0), ('a', 1), ('b', 2), ('dest', 3), ('c', 4), ('d', 5)])

# %%
tmp = ng.Graph(
    g,
    layout="dot",
    arrows=True,
    weighted=True,
    # node_color={x:colors[x] for x in g.nodes}, # TODO: this based on src/dest/normal
    node_labels={x:i for x,i in zip(g.nodes, gm.nodes)},
    node_shape = "8", #so^>v<dph8
    edge_cmap='PRGn',
    )

# %%
import matplotlib.pyplot as plt

# %%
ax = plt.gca()

# %%
gm.plot(ax)
